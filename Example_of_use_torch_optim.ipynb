# %%
import torch
from optim_sam import main
from torchvision.models import resnet18

torch.manual_seed(0)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = resnet18(num_classes=10).to(device)
losses = main(
    dataset         = "cifar10",
    device          = device,
    bayesian        = True,
    lr              = 0.05,
    beta1           = 0.9,
    beta2           = 0.999,
    priorprec       = 40.0,
    rho             = 0.05,
    s_init          = 1.0,
    damping         = 0.1,
    epochs          = 180,
    warmup          = 5,
    batchsize       = 128,
    testbatchsize   = 128,
    datasetfolder   = "datasets",
    augment         = True,
)
